# %%
import tensorflow as tf

# (optional but recommended) GPU memory growth
gpus = tf.config.list_physical_devices("GPU")
for g in gpus:
    try:
        tf.config.experimental.set_memory_growth(g, True)
    except Exception as e:
        print("Could not set memory growth for", g, ":", e)

print("TF version:", tf.__version__)
print("GPUs:", gpus)

import json
from pathlib import Path

import numpy as np
import pandas as pd
keras = tf.keras
from keras import layers, models
# Out:
# TF version: 2.16.1
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
# EDIT this to where your splits.json lives
SPLITS_FILE = Path('splits.json')
BASE_DIR = SPLITS_FILE.parent

print("SPLITS_FILE:", SPLITS_FILE)
print("BASE_DIR   :", BASE_DIR)
print("Exists? splits:", SPLITS_FILE.exists(), "  base:", BASE_DIR.exists())
# Out:
# SPLITS_FILE: splits.json
# BASE_DIR   : .
# Exists? splits: True   base: True

# %% [markdown]
# ### Load splits.json & build a DataFrame

# %%
with open(SPLITS_FILE, "r") as f:
    splits = json.load(f)
print("Keys in splits:", list(splits.keys()))
for k in splits:
    print(k, ":", len(splits[k]), "images")
    for i in range(len(splits[k])):
        splits[k][i] = splits[k][i].replace("\\", "/")
rows = []
for split_name, rel_paths in splits.items():
    for rel in rel_paths:
        rel_path = Path(rel)
        img_path = BASE_DIR / rel_path
        cls = img_path.parent.name
        rows.append({
            "split": split_name,
            "class_name": cls,
            "image_path": str(img_path),
        })

df = pd.DataFrame(rows)
df["split"].value_counts(), df["class_name"].value_counts()
# Out:
# Keys in splits: ['train', 'val', 'test']
# train : 839 images
# val : 180 images
# test : 181 images
# (split
#  train    839
#  test     181
#  val      180
#  Name: count, dtype: int64,
#  class_name
#  Corals          200
#  Ammonites       200
#  Belemnites      200
#  Crinoids        200
#  Leaf fossils    200
#  Trilobites      200
#  Name: count, dtype: int64)

# %% [markdown]
# ### Label encoding & file lists per split

# %%
classes = sorted(df["class_name"].unique())
class_to_idx = {c: i for i, c in enumerate(classes)}
idx_to_class = {i: c for c, i in class_to_idx.items()}

print("Classes:", classes)
print("Mapping:", class_to_idx)
def get_file_label_arrays(split_name):
    sub = df[df["split"] == split_name].copy()
    filepaths = sub["image_path"].values.astype(str)
    labels = sub["class_name"].map(class_to_idx).values.astype(np.int32)
    print(f"{split_name}: {len(filepaths)} images")
    return filepaths, labels

train_files, train_labels = get_file_label_arrays("train")
val_files,   val_labels   = get_file_label_arrays("val")
test_files,  test_labels  = get_file_label_arrays("test")
# Out:
# Classes: ['Ammonites', 'Belemnites', 'Corals', 'Crinoids', 'Leaf fossils', 'Trilobites']
# Mapping: {'Ammonites': 0, 'Belemnites': 1, 'Corals': 2, 'Crinoids': 3, 'Leaf fossils': 4, 'Trilobites': 5}
# train: 839 images
# val: 180 images
# test: 181 images

# %% [markdown]
# ### tf.data loader (image → tensor)

# %%
IMG_SIZE = 224
BATCH_SIZE = 128
AUTOTUNE = tf.data.AUTOTUNE

def load_and_preprocess(path, label):
    # path: scalar string tensor
    img_bytes = tf.io.read_file(path)
    # decode (handles JPEG/PNG)
    img = tf.io.decode_image(img_bytes, channels=3, expand_animations=False)
    img = tf.image.convert_image_dtype(img, tf.float32)  # [0,1]
    img = tf.image.resize(img, (IMG_SIZE, IMG_SIZE))
    return img, label

# %% [markdown]
# ### Build train/val/test datasets

# %%
def make_dataset(filepaths, labels, batch_size=BATCH_SIZE, training=False):
    ds = tf.data.Dataset.from_tensor_slices((filepaths, labels))
    if training:
        ds = ds.shuffle(len(filepaths), reshuffle_each_iteration=True)
    ds = ds.map(load_and_preprocess, num_parallel_calls=AUTOTUNE)
    ds = ds.batch(batch_size).prefetch(AUTOTUNE)
    return ds

train_ds = make_dataset(train_files, train_labels, training=True)
val_ds   = make_dataset(val_files,   val_labels,   training=False)
test_ds  = make_dataset(test_files,  test_labels,  training=False)

train_ds, val_ds, test_ds
# Out:
# (<_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>,
#  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>,
#  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>)

# %% [markdown]
# ### Define a ResNet50 model in Keras (TensorFlow)

# %%
from keras.applications import ResNet50
from keras.applications.resnet50 import preprocess_input
tf.config.optimizer.set_jit(False)
num_classes = len(classes)

data_augmentation = tf.keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.1),
    ],
    name="data_augmentation"
)

base_model = ResNet50(
    include_top=False,
    weights="imagenet",
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    pooling="avg",  # global average pooling
)

base_model.trainable = False  # first train only the new head

inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)          # ResNet preprocessing
x = base_model(x, training=False)

x = layers.Dense(512, activation="relu")(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(num_classes, activation="softmax")(x)

fine_tune_from = len(base_model.layers) // 2

for i, layer in enumerate(base_model.layers):
    layer.trainable = (i >= fine_tune_from)
    
model = tf.keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ data_augmentation   │ (None, 224, 224,  │          0 │ input_layer_7[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_6          │ (None, 224, 224)  │          0 │ data_augmentatio… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_7          │ (None, 224, 224)  │          0 │ data_augmentatio… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_8          │ (None, 224, 224)  │          0 │ data_augmentatio… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack_2 (Stack)     │ (None, 224, 224,  │          0 │ get_item_6[0][0], │
# │                     │ 3)                │            │ get_item_7[0][0], │
# │                     │                   │            │ get_item_8[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 224, 224,  │          0 │ stack_2[0][0]     │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50            │ (None, 2048)      │ 23,587,712 │ add_2[0][0]       │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 512)       │  1,049,088 │ resnet50[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 512)       │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │     65,664 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128)       │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 6)         │        774 │ dropout_4[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,703,238 (94.24 MB)
#  Trainable params: 1,115,526 (4.26 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %% [markdown]
# ### Compile & train (frozen backbone)

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint


print("Trainable layers:", sum(layer.trainable for layer in base_model.layers), "of", len(base_model.layers))

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

RESULTS_DIR = Path("results/resnet50 training")
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

checkpoint_path = RESULTS_DIR / "resnet50_geo_fossil_frozen_best.keras"

callbacks = [
    EarlyStopping(
        monitor="val_accuracy",
        patience=15,
        restore_best_weights=True,
        verbose=0,
    ),
    ModelCheckpoint(
        filepath=str(checkpoint_path),
        monitor="val_accuracy",
        save_best_only=True,
        verbose=0,
    ),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=200,
    callbacks=callbacks,
)
# Out:
# Trainable layers: 88 of 176
# Epoch 1/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.2603 - loss: 1.8035 - val_accuracy: 0.1444 - val_loss: 1.8762
# Epoch 2/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 756ms/step - accuracy: 0.5543 - loss: 1.1969 - val_accuracy: 0.1500 - val_loss: 1.8793
# Epoch 3/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 731ms/step - accuracy: 0.5931 - loss: 1.0471 - val_accuracy: 0.1778 - val_loss: 1.8769
# Epoch 4/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 767ms/step - accuracy: 0.6600 - loss: 0.9214 - val_accuracy: 0.2056 - val_loss: 1.8628
# Epoch 5/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 706ms/step - accuracy: 0.7399 - loss: 0.7717 - val_accuracy: 0.2500 - val_loss: 1.8426
# Epoch 6/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 639ms/step - accuracy: 0.7573 - loss: 0.7268 - val_accuracy: 0.1889 - val_loss: 1.8568
# Epoch 7/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 635ms/step - accuracy: 0.7644 - loss: 0.7246 - val_accuracy: 0.1778 - val_loss: 1.8102
# Epoch 8/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 641ms/step - accuracy: 0.7715 - loss: 0.6828 - val_accuracy: 0.1889 - val_loss: 1.9454
# Epoch 9/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 653ms/step - accuracy: 0.8324 - loss: 0.5740 - val_accuracy: 0.1944 - val_loss: 1.9426
# Epoch 10/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 639ms/step - accuracy: 0.8334 - loss: 0.5623 - val_accuracy: 0.1944 - val_loss: 2.1717
# Epoch 11/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 641ms/step - accuracy: 0.7970 - loss: 0.5784 - val_accuracy: 0.2167 - val_loss: 1.8252
# Epoch 12/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 623ms/step - accuracy: 0.8437 - loss: 0.4716 - val_accuracy: 0.2111 - val_loss: 1.8561
# Epoch 13/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 762ms/step - accuracy: 0.8624 - loss: 0.4184 - val_accuracy: 0.2833 - val_loss: 1.7191
# Epoch 14/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 740ms/step - accuracy: 0.8491 - loss: 0.4831 - val_accuracy: 0.3833 - val_loss: 1.6052
# Epoch 15/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 730ms/step - accuracy: 0.8539 - loss: 0.4178 - val_accuracy: 0.4056 - val_loss: 1.6399
# Epoch 16/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 638ms/step - accuracy: 0.8702 - loss: 0.3877 - val_accuracy: 0.3944 - val_loss: 1.7273
# Epoch 17/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.8839 - loss: 0.3340 - val_accuracy: 0.4389 - val_loss: 1.7187
# Epoch 18/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 644ms/step - accuracy: 0.8764 - loss: 0.3406 - val_accuracy: 0.4000 - val_loss: 2.3866
# Epoch 19/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 749ms/step - accuracy: 0.8797 - loss: 0.3661 - val_accuracy: 0.4500 - val_loss: 1.9052
# Epoch 20/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 689ms/step - accuracy: 0.8822 - loss: 0.3661 - val_accuracy: 0.4389 - val_loss: 2.6096
# Epoch 21/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 763ms/step - accuracy: 0.8895 - loss: 0.3324 - val_accuracy: 0.4722 - val_loss: 2.3044
# Epoch 22/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 638ms/step - accuracy: 0.9124 - loss: 0.2770 - val_accuracy: 0.4667 - val_loss: 2.5691
# Epoch 23/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 722ms/step - accuracy: 0.9161 - loss: 0.2540 - val_accuracy: 0.6278 - val_loss: 1.5732
# Epoch 24/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 805ms/step - accuracy: 0.8877 - loss: 0.3174 - val_accuracy: 0.6722 - val_loss: 1.0976
# Epoch 25/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 687ms/step - accuracy: 0.9164 - loss: 0.2636 - val_accuracy: 0.6444 - val_loss: 1.3356
# Epoch 26/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 647ms/step - accuracy: 0.8921 - loss: 0.3244 - val_accuracy: 0.6278 - val_loss: 1.3303
# Epoch 27/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 753ms/step - accuracy: 0.8999 - loss: 0.2935 - val_accuracy: 0.7389 - val_loss: 0.8077
# Epoch 28/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 668ms/step - accuracy: 0.9057 - loss: 0.3309 - val_accuracy: 0.6778 - val_loss: 1.0995
# Epoch 29/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 650ms/step - accuracy: 0.9014 - loss: 0.2916 - val_accuracy: 0.5944 - val_loss: 1.6318
# Epoch 30/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 665ms/step - accuracy: 0.9043 - loss: 0.2900 - val_accuracy: 0.5833 - val_loss: 2.4043
# Epoch 31/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 638ms/step - accuracy: 0.8914 - loss: 0.2976 - val_accuracy: 0.6556 - val_loss: 1.4828
# Epoch 32/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 643ms/step - accuracy: 0.9196 - loss: 0.2456 - val_accuracy: 0.5111 - val_loss: 3.1537
# Epoch 33/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 626ms/step - accuracy: 0.9251 - loss: 0.2273 - val_accuracy: 0.5556 - val_loss: 2.6506
# Epoch 34/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 652ms/step - accuracy: 0.9299 - loss: 0.2439 - val_accuracy: 0.6778 - val_loss: 1.2924
# Epoch 35/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 760ms/step - accuracy: 0.9535 - loss: 0.1468 - val_accuracy: 0.7667 - val_loss: 0.8210
# Epoch 36/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 714ms/step - accuracy: 0.9402 - loss: 0.1683 - val_accuracy: 0.8000 - val_loss: 0.7314
# Epoch 37/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 667ms/step - accuracy: 0.9358 - loss: 0.1841 - val_accuracy: 0.7944 - val_loss: 0.7717
# Epoch 38/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 715ms/step - accuracy: 0.9488 - loss: 0.1776 - val_accuracy: 0.8167 - val_loss: 0.6473
# Epoch 39/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 659ms/step - accuracy: 0.9270 - loss: 0.2110 - val_accuracy: 0.6611 - val_loss: 1.7281
# Epoch 40/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 673ms/step - accuracy: 0.9586 - loss: 0.1524 - val_accuracy: 0.6944 - val_loss: 1.1179
# Epoch 41/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 650ms/step - accuracy: 0.9421 - loss: 0.1623 - val_accuracy: 0.6222 - val_loss: 1.3718
# Epoch 42/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 648ms/step - accuracy: 0.9201 - loss: 0.2617 - val_accuracy: 0.6556 - val_loss: 1.3425
# Epoch 43/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 661ms/step - accuracy: 0.9249 - loss: 0.1965 - val_accuracy: 0.7500 - val_loss: 1.2426
# Epoch 44/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 639ms/step - accuracy: 0.9421 - loss: 0.1978 - val_accuracy: 0.7389 - val_loss: 1.3411
# Epoch 45/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 619ms/step - accuracy: 0.9543 - loss: 0.1524 - val_accuracy: 0.7444 - val_loss: 1.1511
# Epoch 46/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 773ms/step - accuracy: 0.9580 - loss: 0.1502 - val_accuracy: 0.8278 - val_loss: 0.7731
# Epoch 47/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 843ms/step - accuracy: 0.9369 - loss: 0.1807 - val_accuracy: 0.8556 - val_loss: 0.7161
# Epoch 48/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.9453 - loss: 0.1439

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.plot(history.history["accuracy"], label="train_acc")
plt.plot(history.history["val_accuracy"], label="val_acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.title("ResNet50 training/validation accuracy")
plt.tight_layout()
plt.savefig(RESULTS_DIR / "resnet50_acc.png", dpi=300, bbox_inches="tight")
plt.show()


# Loss
plt.figure(figsize=(6,4))
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("ResNet50 training/validation loss")
plt.tight_layout()
plt.savefig(RESULTS_DIR / "resnet50_loss.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Evaluate on test set + confusion matrix

# %%
test_loss, test_acc = model.evaluate(test_ds)
print("Test accuracy:", test_acc)

# %%
# Get predictions and confusion matrix
y_true = []
y_pred = []

for batch_imgs, batch_labels in test_ds:
    preds = model.predict(batch_imgs, verbose=0)
    y_true.extend(batch_labels.numpy().tolist())
    y_pred.extend(np.argmax(preds, axis=1).tolist())

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

cm = confusion_matrix(y_true, y_pred, labels=list(range(num_classes)))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)

plt.figure(figsize=(6, 6))
disp.plot(include_values=True, cmap="Blues", ax=plt.gca(), xticks_rotation=45)
plt.title("Confusion matrix – ResNet50 (TensorFlow)")
plt.tight_layout()
cm_path = RESULTS_DIR / "cm_resnet50_tf.png"
plt.savefig(cm_path, dpi=300, bbox_inches="tight")
plt.show()

print("Saved confusion matrix to:", cm_path)
print("\nClassification report:")
print(classification_report(y_true, y_pred, target_names=classes, digits=3))

# %%
# from tensorflow import keras
# model = keras.models.load_model("results/resnet50_geo_fossil_frozen_best.keras")
